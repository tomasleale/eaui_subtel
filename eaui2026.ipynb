# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/Users/tomas/GitHub/eaui_subtel/data/2026.xlsx')

# %%
df['P5_1 .- ¿Con qué compañía tiene contratado el servicio de? : Banda ancha Fija'].value_counts(dropna=False)
# Out:
# P5_1 .- ¿Con qué compañía tiene contratado el servicio de? : Banda ancha Fija
# NaN              1703
# Movistar         1037
# Vtr               636
# Mundo             512
# Claro             300
# Entel             296
# Telsur            194
# Wom                88
# No recuerda        51
# Otra               33
# Directv            18
# Novavision         18
# Telconor           13
# Tv pencahue        12
# Intercom            8
# Binet               8
# Wiriles             8
# Gtd Manquehue       7
# Go sur              6
# Hotmet              6
# Megafibra           5
# Arpanet             5
# Net Sur             5
# Geo net             5
# Multicom            4
# Homenet             4
# Artec               3
# Nivit               3
# Hase plus           3
# Global              2
# Airnet              2
# Turbo net           2
# Anmax               1
# Asin com            1
# Giga red            1
# Name: count, dtype: int64
